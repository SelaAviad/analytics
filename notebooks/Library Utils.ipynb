# %%
# %%writefile  cosutils.py


# Utility Functions for Cloud Object 
from botocore.exceptions import ClientError

# Create new bucket
def create_bucket(cos, bucket_name):
    print("Creating new bucket: {0}".format(bucket_name))
    try:
        cos.Bucket(bucket_name).create(
            CreateBucketConfiguration={
                "LocationConstraint":COS_BUCKET_LOCATION
            }
        )
        print("Bucket: {0} created!".format(bucket_name))
    except ClientError as be:
        print("CLIENT ERROR: {0}\n".format(be))
    except Exception as e:
        print("Unable to create bucket: {0}".format(e))

        
# List Available buckets
def list_all_buckets(cos):
    print("Retrieving list of buckets")
    try:
        buckets = cos.buckets.all()
        for bucket in buckets:
            print("Bucket Name: {0}".format(bucket.name))
    except ClientError as be:
        print("CLIENT ERROR: {0}\n".format(be))        
    except Exception as e:        
        print("Unable to retrieve list buckets: {0}".format(e))
    
#     try:        
#         for bucket in cos.buckets.all():
#             print("Bucket Name : " , bucket.name)        
#             try:
#                 for obj in bucket.objects.all():
#                     print("  -  " , obj.key) 
#             except:
#                 print(" - Object Access - Unexpected error: ", sys.exc_info()[0])
#     except  Exception as inst:
#         print(" - Bucket Access - Unexpected error: ", sys.exc_info()[0])
#         # print(type(inst))    # the exception instance
#         print(inst.args)        
#     return


# List all buckets items
def list_all_buckets_items(cos):
    print("Retrieving Items for all buckets")
    try:
        buckets = cos.buckets.all()
        for bucket in buckets:
            print("Bucket Name: {0}".format(bucket.name))
            for obj in bucket.objects.all():
              print("  - ", obj.key)            
    except ClientError as be:
        print("CLIENT ERROR: {0}\n".format(be))        
    except Exception as e:        
        print("Unable to retrieve list buckets: {0}".format(e))

# List Object in a bucket        
def get_bucket_contents(cos):    
    print("Retrieving Contents for all buckets")
    try:
        buckets = cos.buckets.all()
        for bucket in buckets:
            print("Bucket Name: {0}".format(bucket.name))
            get_bucket_contents(cos, bucket.name)
    except ClientError as be:
        print("CLIENT ERROR: {0}\n".format(be))
    except Exception as e:
        print("Unable to retrieve bucket contents: {0}".format(e))                
        
# List Object in a bucket        
def get_bucket_contents_by_name(cos, bucket_name):
    print("Retrieving bucket contents from: {0}".format(bucket_name))
    try:
        files = cos.Bucket(bucket_name).objects.all()
        for file in files:
            print("Item: {0} ({1} bytes).".format(file.key, file.size))
    except ClientError as be:
        print("CLIENT ERROR: {0}\n".format(be))
    except Exception as e:
        print("Unable to retrieve bucket contents: {0}".format(e))
# Out:
# Overwriting cosutils.py

# %%
import cosutils as learncos
import ibm_boto3
from botocore.client import Config

editorCos = ibm_boto3.resource('s3',
                      ibm_api_key_id='6iIum3IqOx1yT_j-41XLWC4efgWvLpWl9GygORQ2w3Mu',
                      ibm_service_instance_id='crn:v1:bluemix:public:cloud-object-storage:global:a/3f8db8ad664d6b96415519a4276fce0e:b60f913b-5fbf-4af3-98d8-b4d2e59e6ac4::',
                      ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
                      config=Config(signature_version='oauth'),
                      endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

adminCos = ibm_boto3.resource('s3',
                      ibm_api_key_id='FNZl0YO3oTgaM-NCL5k0yaMyGs75s1865LoRDMA1cxiw',
                      ibm_service_instance_id='crn:v1:bluemix:public:cloud-object-storage:global:a/3f8db8ad664d6b96415519a4276fce0e:b60f913b-5fbf-4af3-98d8-b4d2e59e6ac4::',
                      ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
                      config=Config(signature_version='oauth'),
                      endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

catalogCos = ibm_boto3.resource('s3',
                      ibm_api_key_id='39-XwUlSW4s1FQ_LHJhvEZWaScdChqKGiEyUUp2nxDeY',
                      ibm_service_instance_id='crn:v1:bluemix:public:cloud-object-storage:global:a/3f8db8ad664d6b96415519a4276fce0e:b60f913b-5fbf-4af3-98d8-b4d2e59e6ac4::',
                      ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
                      config=Config(signature_version='oauth'),
                      endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')


# Admin COS credentials works partially, not for the catalog bucket
print("Calling with ADMIN Crednetials (WDP-Admin-b60f913b-5fbf-4af3-98d8-b4d2e59e6ac4)")
learncos.list_all_buckets(adminCos)

# Editor COS does not have access permissions
print("\nCalling with Editor Crednetials (WDP-Editor-analyticslearning-donotdelete-pr-xijmbycnsrg0hm)")
learncos.list_all_buckets(editorCos)

# CATALOG works partially, not for the catalog bucket
print("\nCalling with CATALOG Crednetials (WDP-Catalog-ManagerV2)")
learncos.list_all_buckets(catalogCos)


learncos.list_all_buckets_items(adminCos)
# Out:
# Calling with ADMIN Crednetials (WDP-Admin-b60f913b-5fbf-4af3-98d8-b4d2e59e6ac4)
# Retrieving list of buckets
# Bucket Name: analyticslearning-donotdelete-pr-xijmbycnsrg0hm
# Bucket Name: learn-demo
# Bucket Name: learningcatalog-datacatalog-skhvvc57
# Bucket Name: sql-28f85c81-6f4b-42dc-8ef5-2196086581ce
#
# Calling with Editor Crednetials (WDP-Editor-analyticslearning-donotdelete-pr-xijmbycnsrg0hm)
# Retrieving list of buckets
# Unable to retrieve list buckets: An error occurred (AccessDenied) when calling the ListBuckets operation: Access Denied
#
# Calling with CATALOG Crednetials (WDP-Catalog-ManagerV2)
# Retrieving list of buckets
# Bucket Name: analyticslearning-donotdelete-pr-xijmbycnsrg0hm
# Bucket Name: learn-demo
# Bucket Name: learningcatalog-datacatalog-skhvvc57
# Bucket Name: sql-28f85c81-6f4b-42dc-8ef5-2196086581ce
# Retrieving Items for all buckets
# Bucket Name: analyticslearning-donotdelete-pr-xijmbycnsrg0hm
#   -  Dr. Baraa Saleh Darawshe_WHLOG_1533363652778.csv
# ...

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Overwriting projutils.py

# %%
from projutils import project


print('Project Name: {0}'.format(project.get_name()))
print('Project Description: {0}'.format(project.get_description()))
print('\nProject Metadata: {0}'.format(project.get_metadata()))
print('\nProject project_bucket_name: {0}'.format(project.get_project_bucket_name()))
print('\nProject Assets (Connections): {0}'.format(project.get_assets(asset_type='connection')))
print('\nProject Connections: {0}'.format(project.get_connections()))
print('\nProject Connection (SQL-COS): {0}'.format(project.get_connection(name='SQL-COS')))
print('\nProject Assets (all): {0}'.format(project.get_assets()))
print('\nProject Files (all): {0}'.format(project.get_files()))
#print('\nProject Connected Data (SQL-Results): {0}'.format(project.get_connected_data(name='Learning-COS')))
# Out:
# Project Name: Analytics-Learning
# Project Description: Use to get hands on with IBM technology for Analytics and ML
#
# ...

# %%
learningCosCred = project.get_connection(name='COS-All-Learning')
learningCosCred
print('\nProject Connection (Learning-COS): {0}'.format(learningCosCred))
learningCos = ibm_boto3.resource('s3',
                      ibm_api_key_id=learningCosCred['api_key'],
                      ibm_service_instance_id=learningCosCred['resource_instance_id'],
                      ibm_auth_endpoint=learningCosCred['iam_url'],
                      config=Config(signature_version='oauth'),
                      endpoint_url=learningCosCred['url'])

print("Calling with All COS credentials (cos-all-cos)")
learncos.list_all_buckets(learningCos)
# Out:
# Project Connection (Learning-COS): {'iam_url': 'https://iam.ng.bluemix.net/oidc/token', 'api_key': '1sVgH8Whsp4zi3qn5kCw_FyggNFacukPXblICmR5pxC0', 'url': 'https://s3-api.us-geo.objectstorage.service.networklayer.com', 'resource_instance_id': 'crn:v1:bluemix:public:cloud-object-storage:global:a/3f8db8ad664d6b96415519a4276fce0e:b60f913b-5fbf-4af3-98d8-b4d2e59e6ac4::'}
# Calling with All COS credentials (cos-all-cos)
# Retrieving list of buckets
# Bucket Name: analyticslearning-donotdelete-pr-xijmbycnsrg0hm
# Bucket Name: learn-demo
# Bucket Name: learningcatalog-datacatalog-skhvvc57
# Bucket Name: sql-28f85c81-6f4b-42dc-8ef5-2196086581ce

# %%
# !pwd
# Out:
# /home/dsxuser/work

# %%
# !pip install py_d3
# Out:
# Requirement not upgraded as not directly required: py_d3 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages
# Requirement not upgraded as not directly required: ipython in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from py_d3)
# Requirement not upgraded as not directly required: setuptools>=18.5 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from ipython->py_d3)
# Requirement not upgraded as not directly required: jedi>=0.10 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from ipython->py_d3)
# Requirement not upgraded as not directly required: decorator in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from ipython->py_d3)
# Requirement not upgraded as not directly required: pickleshare in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from ipython->py_d3)
# Requirement not upgraded as not directly required: simplegeneric>0.8 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from ipython->py_d3)
# ...

# %%
# %load_ext py_d3
# Out:
# The py_d3 extension is already loaded. To reload it, use:
#   %reload_ext py_d3

# %%
# %%d3
# <g><g>
# <script>
# d3.select("g").text("hello world")
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3"
#     }
# });
#
# require(["d3"], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select1 = function(selection) {
#     return _select("#d3-cell-1").select(selection);
# }
# d3.selectAll1 = function(selection) {
#     return _select("#d3-cell-1").selectAll(selection);
# }
# </script>
#
# <g id="d3-cell-1">
#         <g><g>
# <script>
# d3.select1("g").text("hello world")
# </script>
# </g>

# %%
import requests
import json
import uuid

service_URL = "https://api.dataplatform.cloud.ibm.com"
#service_URL = "https://api.dataplatform.ibm.com"
# Replace <IAM Access Token> with your generated IAM Access Token
authorization = "Bearer eyJraWQiOiIyMDE3MTAzMC0wMDowMDowMCIsImFsZyI6IlJTMjU2In0.....iNgdv1gdyEf1nG8GdcEMeOIabWxaD65VIDFMirBRjtY19CcRlS08bSzHTHVIhZ8Cm_zq1L-KMfkaZWdlsUFKXrrIppwm_XV89aPF4tPzDUVy-OoLV8Zx0KyrwJt9ddop2MQqp-PsYV9U67w8WcVE_gI5DQtCmuNv4IGdoeGabirDziqx3GH7h3lgicAYEBv80dylFBtWHSOv9iG9Y6LiKWjhXciL9iOFRoW_y6lN8XwEX7cnHlkNZLcBeXazSG6W9T-NFB7JjY4iyLwBuZzRV5JMPg0cZlOJB19r4LbvOnsx9VNjEHZ1YaProkZ1rtB3cZZUFaYhiemUnyWmGt4hjw"

# GET https://api.dataplatform.ibm.com/v2/projects

def pretty_print(json_content):
    parsed_json = json.loads(json_content)
    print(json.dumps(parsed_json, indent=4, sort_keys=True))

def _parse_response_as_json(req):
    try:
        return req.json()
    except:
        print("response can not be parsed!")
    return None

def _add_data_asset_url(project_id):    
    return "{}/v2/data_assets?project_id={}".format(service_URL, project_id)

def _add_attachment_url(project_id, asset_id):
    return "{}/v2/assets/{}/attachments?project_id={}".format(service_URL, asset_id, project_id)


project_response = requests.get(service_URL + "/v2/projects", headers={'Authorization': authorization},allow_redirects=False)
if project_response.status_code == 301:
    print("Calling redirect " + project_response.headers["location"])
    project_response = requests.get(project_response.headers["location"], headers={'Authorization': authorization})

print(project_response.url)
print(project_response.status_code)
print(project_response.history)    
pretty_print(project_response.text)
projects_ = json.loads(project_response.text)["resources"]
projects = []

for project in projects_:
    projects.append([project["metadata"]["guid"], project["entity"]["name"]])

projects
# Out:
# https://api.dataplatform.cloud.ibm.com/v2/projects
# 200
# []
# {
#     "resources": [
#         {
#             "entity": {
#                 "catalog": {
#                     "guid": "5d75a1ba-2688-4557-a0a8-26dce4ef112f",
#                     "public": false
#                 },
#                 "compute": [
#                     {
#                         "credentials": {
#                             "cluster_master_url": "https://spark.bluemix.net",
#                             "instance_id": "1cb80463-c539-4198-8588-9b644d88be03",
#                             "plan": "ibm.SparkService.PayGoPersonal",
#                             "tenant_id": "s588-9b644d88be034f-593e259dcdc6",
#                             "tenant_id_full": "1cb80463-c539-4198-8588-9b644d88be03_1708db9e-e3cb-4a5a-a24f-593e259dcdc6",
#                             "tenant_secret": "ebcefa3f-b809-44e9-ac3c-c117523d92f4"
#                         },
# ...

# %%
data_assets_create_params = {        
    "project_id" : "404843c4-4162-494b-b7f3-fd64559394a7"
}

ASSET_TYPE_DATA_ASSET="data_asset"
filename="stream_raw_20181111_164501.csv"
mime="text/csv"

data_assets_create_query = {
    "metadata" : {
       "asset_type":ASSET_TYPE_DATA_ASSET,
        "name":filename,
        "origin_country":"us"
    },
    "entity" : {
        "data_asset" : {
            "dataset": False,
            "mime_type":mime    
        }        
    }
}


attachment_create_query = {
    "asset_type": ASSET_TYPE_DATA_ASSET, 
    "name": filename, 
    "mime": mime, 
    "object_key": filename, 
    "object_key_is_read_only": True
}


request_dataasset = requests.post(service_URL+"/v2/data_assets", headers={'Authorization': authorization}, json=data_assets_create_query, params=data_assets_create_params)
print("Data Asset Created: "  + request_dataasset.text)
print(request_dataasset.status_code)

asset_obj = _parse_response_as_json(request_dataasset)
if (asset_obj):
  asset_id = asset_obj.get("asset_id")
  requst_attachment = requests.post(_add_attachment_url(data_assets_create_params["project_id"],asset_id), headers={'Authorization': authorization}, json=attachment_create_query)
  #print("Data Attachment Created: "  + requst_attachment)
  print("Data Attachment Created: {}".format(_parse_response_as_json(requst_attachment)))
# Out:
# Data Asset Created: {"metadata":{"rov":{"mode":0,"collaborator_ids":{}},"project_id":"404843c4-4162-494b-b7f3-fd64559394a7","sandbox_id":"404843c4-4162-494b-b7f3-fd64559394a7","usage":{"last_updated_at":"2018-11-14T14:00:25Z","last_updater_id":"IBMid-27000067CX","last_update_time":1542204025171,"last_accessed_at":"2018-11-14T14:00:25Z","last_access_time":1542204025171,"last_accessor_id":"IBMid-27000067CX","access_count":0},"name":"stream_raw_20181111_164501.csv","description":"","tags":[],"asset_type":"data_asset","origin_country":"us","rating":0.0,"total_ratings":0,"catalog_id":"1ebee9d2-543c-4716-a993-ae4f89e018ee","created":1542204025171,"created_at":"2018-11-14T14:00:25Z","owner_id":"IBMid-27000067CX","size":0,"version":2.0,"asset_state":"available","asset_attributes":["data_asset"],"asset_id":"ba96f757-25d8-43f9-9cc4-c633b7df2fbf","asset_category":"USER"},"entity":{"data_asset":{"mime_type":"text/csv","dataset":false}},"href":"https://api.dataplatform.cloud.ibm.com/v2/data_asset
# ...

# %%
project_response = requests.get(service_URL + "/v2/data_assets/5850c6c3-6135-4d51-840f-68ed67f93fd5", headers={'Authorization': authorization},allow_redirects=False,  params=data_assets_create_params)
if project_response.status_code == 301:
    print("Calling redirect " + project_response.headers["location"])
    project_response = requests.get(project_response.headers["location"], headers={'Authorization': authorization})

print(project_response.url)
print(project_response.status_code)
print(project_response.history)    
pretty_print(project_response.text)
# Out:
# https://api.dataplatform.cloud.ibm.com/v2/data_assets/5850c6c3-6135-4d51-840f-68ed67f93fd5?project_id=404843c4-4162-494b-b7f3-fd64559394a7
# 200
# []
# {
#     "attachments": [
#         {
#             "asset_type": "data_asset",
#             "complete_time_ticks": 1535456662901,
#             "create_time": 1535456662901,
#             "creator_id": "IBMid-27000067CX",
#             "handle": {
#                 "bucket": "analyticslearning-donotdelete-pr-xijmbycnsrg0hm",
#                 "key": "UNdata_life_expectancy_at_birth_total_years.csv",
#                 "location": "us-geo",
#                 "max_part_num": 1,
#                 "upload_id": "done"
#             },
#             "id": "449113ef-8471-4b23-a972-9646e64accb3",
#             "is_managed": false,
#             "is_object_key_read_only": true,
#             "is_partitioned": false,
#             "is_referenced": true,
#             "is_remote": false,
#             "is_user_provided_path_key": true,
# ...

# %%
project_response = requests.get(service_URL + "/v2/catalogs", headers={'Authorization': authorization})
if project_response.status_code == 301:
    print("Calling redirect " + project_response.headers["location"])
    project_response = requests.get(project_response.headers["location"], headers={'Authorization': authorization})

print(project_response.url)
print(project_response.status_code)
print(project_response.history)    
pretty_print(project_response.text)
# Out:
# https://api.dataplatform.cloud.ibm.com/v2/catalogs
# 200
# []
# {
#     "catalogs": [
#         {
#             "entity": {
#                 "bss_account_id": "3f8db8ad664d6b96415519a4276fce0e",
#                 "capacity_limit": 0,
#                 "description": "",
#                 "generator": "Catalog-UI-Service",
#                 "is_governed": false,
#                 "name": "Learning Catalog",
#                 "saml_instance_name": "IBM w3id"
#             },
#             "href": "https://api.dataplatform.cloud.ibm.com/v2/catalogs/0d60e970-1d0e-4039-8a22-d29ae1c71fd3",
#             "metadata": {
#                 "create_time": "2018-10-09T10:34:44Z",
#                 "creator_id": "IBMid-27000067CX",
#                 "guid": "0d60e970-1d0e-4039-8a22-d29ae1c71fd3",
#                 "url": "https://api.dataplatform.cloud.ibm.com/v2/catalogs/0d60e970-1d0e-4039-8a22-d29ae1c71fd3"
#             }
#         }
#     ],
# ...
